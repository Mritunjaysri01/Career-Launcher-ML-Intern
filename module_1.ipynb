# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('INFY.csv')

# %%
df
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0     INFY     EQ  15-May-2017      964.25      963.50      963.50     949.10
# 1     INFY     EQ  16-May-2017      951.55      953.10      960.15     946.95
# 2     INFY     EQ  17-May-2017      955.00      951.60      958.45     943.85
# 3     INFY     EQ  18-May-2017      952.80      943.00      973.90     942.85
# 4     INFY     EQ  19-May-2017      961.75      961.50      962.70     947.85
# ..     ...    ...          ...         ...         ...         ...        ...
# 491   INFY     EQ  07-May-2019      718.40      720.40      727.90     718.70
# 492   INFY     EQ  08-May-2019      724.55      721.00      726.00     716.50
# 493   INFY     EQ  09-May-2019      719.35      719.15      730.30     715.80
# 494   INFY     EQ  10-May-2019      721.05      720.80      726.00     715.00
# 495   INFY     EQ  13-May-2019      716.85      716.55      726.45     712.10
#
# ...

# %%
df.head()
# Out:
#   Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0   INFY     EQ  15-May-2017      964.25       963.5      963.50     949.10
# 1   INFY     EQ  16-May-2017      951.55       953.1      960.15     946.95
# 2   INFY     EQ  17-May-2017      955.00       951.6      958.45     943.85
# 3   INFY     EQ  18-May-2017      952.80       943.0      973.90     942.85
# 4   INFY     EQ  19-May-2017      961.75       961.5      962.70     947.85
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      953.25       951.55         951.49                3648582
# 1      956.00       955.00         952.92                3065084
# 2      952.90       952.80         949.48                1457754
# 3      960.25       961.75         962.61                4028924
# 4      957.40       957.95         954.18                2128698
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
df[df['Series']!='EQ']
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 444   INFY     BL  25-Feb-2019     1220.15      734.95      734.95     734.95
# 462   INFY     BL  22-Mar-2019      734.95      738.95      738.95     738.95
#
#      Last Price  Close Price  Average Price  Total Traded Quantity  \
# 444      734.95       734.95         734.95                1263230
# 462      738.95       738.95         738.95                1727935
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 444  9.284109e+08              1                0                     0.0
# 462  1.276858e+09              1          1727935                   100.0

# %%
df =df.drop(index=444, axis=1)
df[df['Series']!='EQ']
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 462   INFY     BL  22-Mar-2019      734.95      738.95      738.95     738.95
#
#      Last Price  Close Price  Average Price  Total Traded Quantity  \
# 462      738.95       738.95         738.95                1727935
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 462  1.276858e+09              1          1727935                   100.0

# %%
df =df.drop(index=462, axis=1)
df[df['Series']!='EQ']
# Out:
# Empty DataFrame
# Columns: [Symbol, Series, Date, Prev Close, Open Price, High Price, Low Price, Last Price, Close Price, Average Price, Total Traded Quantity, Turnover, No. of Trades, Deliverable Qty, % Dly Qt to Traded Qty]
# Index: []

# %%
df.head()
# Out:
#   Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0   INFY     EQ  15-May-2017      964.25       963.5      963.50     949.10
# 1   INFY     EQ  16-May-2017      951.55       953.1      960.15     946.95
# 2   INFY     EQ  17-May-2017      955.00       951.6      958.45     943.85
# 3   INFY     EQ  18-May-2017      952.80       943.0      973.90     942.85
# 4   INFY     EQ  19-May-2017      961.75       961.5      962.70     947.85
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      953.25       951.55         951.49                3648582
# 1      956.00       955.00         952.92                3065084
# 2      952.90       952.80         949.48                1457754
# 3      960.25       961.75         962.61                4028924
# 4      957.40       957.95         954.18                2128698
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
df.tail(90)
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 404   INFY     EQ  31-Dec-2018      656.95      660.00      662.00     655.80
# 405   INFY     EQ  01-Jan-2019      658.95      660.95      666.30     654.15
# 406   INFY     EQ  02-Jan-2019      665.05      666.00      674.00     662.05
# 407   INFY     EQ  03-Jan-2019      669.05      672.00      677.00     663.10
# 408   INFY     EQ  04-Jan-2019      669.15      671.75      673.90     651.00
# ..     ...    ...          ...         ...         ...         ...        ...
# 491   INFY     EQ  07-May-2019      718.40      720.40      727.90     718.70
# 492   INFY     EQ  08-May-2019      724.55      721.00      726.00     716.50
# 493   INFY     EQ  09-May-2019      719.35      719.15      730.30     715.80
# 494   INFY     EQ  10-May-2019      721.05      720.80      726.00     715.00
# 495   INFY     EQ  13-May-2019      716.85      716.55      726.45     712.10
#
# ...

# %%
df.describe()
# Out:
#         Prev Close   Open Price   High Price    Low Price   Last Price  \
# count   494.000000   494.000000   494.000000   494.000000   494.000000
# mean    961.440789   961.070040   971.092713   951.052733   960.845648
# std     220.761549   220.091227   222.968974   218.714372   220.968590
# min     619.100000   621.000000   628.000000   599.850000   619.500000
# 25%     735.025000   736.187500   742.700000   729.012500   734.125000
# 50%     956.750000   957.525000   964.775000   948.000000   956.025000
# 75%    1150.150000  1145.412500  1161.675000  1135.962500  1147.950000
# max    1441.100000  1449.000000  1467.900000  1430.000000  1440.000000
#
#        Close Price  Average Price  Total Traded Quantity      Turnover  \
# count   494.000000     494.000000           4.940000e+02  4.940000e+02
# mean    960.945749     961.166498           6.056365e+06  5.469840e+09
# std     221.029267     221.102384           5.451445e+06  4.770342e+09
# ...

# %%
df.tail(90).min()
# Out:
# Symbol                           INFY
# Series                             EQ
# Date                      01-Apr-2019
# Prev Close                     656.95
# Open Price                        660
# High Price                        662
# Low Price                         651
# Last Price                      659.6
# Close Price                    658.95
# Average Price                  659.27
# Total Traded Quantity         2943390
# Turnover                  1.94458e+09
# No. of Trades                   45422
# Deliverable Qty               1282161
# % Dly Qt to Traded Qty          36.25
# dtype: object

# %%
df.tail(90).max()
# Out:
# Symbol                           INFY
# Series                             EQ
# Date                      31-Jan-2019
# Prev Close                     767.25
# Open Price                        770
# High Price                        773
# Low Price                         761
# Last Price                     769.15
# Close Price                    767.25
# Average Price                   766.2
# Total Traded Quantity        31574803
# Turnover                  2.28786e+10
# No. of Trades                  566543
# Deliverable Qty              16753549
# % Dly Qt to Traded Qty          74.53
# dtype: object

# %%
df.tail(90).mean()
# Out:
# Prev Close                7.279056e+02
# Open Price                7.285272e+02
# High Price                7.348894e+02
# Low Price                 7.214489e+02
# Last Price                7.285772e+02
# Close Price               7.286028e+02
# Average Price             7.282926e+02
# Total Traded Quantity     8.055477e+06
# Turnover                  5.844801e+09
# No. of Trades             1.642872e+05
# Deliverable Qty           4.527516e+06
# % Dly Qt to Traded Qty    5.635722e+01
# dtype: float64

# %%
df.dtypes
# Out:
# Symbol                     object
# Series                     object
# Date                       object
# Prev Close                float64
# Open Price                float64
# High Price                float64
# Low Price                 float64
# Last Price                float64
# Close Price               float64
# Average Price             float64
# Total Traded Quantity       int64
# Turnover                  float64
# No. of Trades               int64
# Deliverable Qty             int64
# % Dly Qt to Traded Qty    float64
# dtype: object

# %%
df['Date']=df['Date'].astype('datetime64')

# %%
df.dtypes
# Out:
# Symbol                            object
# Series                            object
# Date                      datetime64[ns]
# Prev Close                       float64
# Open Price                       float64
# High Price                       float64
# Low Price                        float64
# Last Price                       float64
# Close Price                      float64
# Average Price                    float64
# Total Traded Quantity              int64
# Turnover                         float64
# No. of Trades                      int64
# Deliverable Qty                    int64
# % Dly Qt to Traded Qty           float64
# dtype: object

# %%
df[df['Series']!='EQ']
# Out:
# Empty DataFrame
# Columns: [Symbol, Series, Date, Prev Close, Open Price, High Price, Low Price, Last Price, Close Price, Average Price, Total Traded Quantity, Turnover, No. of Trades, Deliverable Qty, % Dly Qt to Traded Qty]
# Index: []

# %%
df['Date'].max()
# Out:
# Timestamp('2019-05-13 00:00:00')

# %%
df['Date'].min()
# Out:
# Timestamp('2017-05-15 00:00:00')

# %%
df['Date'].max()-df['Date'].min()
# Out:
# Timedelta('728 days 00:00:00')

# %%
df['Month']=pd.DatetimeIndex(df['Date']).month
df
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0     INFY     EQ 2017-05-15      964.25      963.50      963.50     949.10
# 1     INFY     EQ 2017-05-16      951.55      953.10      960.15     946.95
# 2     INFY     EQ 2017-05-17      955.00      951.60      958.45     943.85
# 3     INFY     EQ 2017-05-18      952.80      943.00      973.90     942.85
# 4     INFY     EQ 2017-05-19      961.75      961.50      962.70     947.85
# ..     ...    ...        ...         ...         ...         ...        ...
# 491   INFY     EQ 2019-05-07      718.40      720.40      727.90     718.70
# 492   INFY     EQ 2019-05-08      724.55      721.00      726.00     716.50
# 493   INFY     EQ 2019-05-09      719.35      719.15      730.30     715.80
# 494   INFY     EQ 2019-05-10      721.05      720.80      726.00     715.00
# 495   INFY     EQ 2019-05-13      716.85      716.55      726.45     712.10
#
# ...

# %%
df['Year']=pd.DatetimeIndex(df['Date']).year
df
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0     INFY     EQ 2017-05-15      964.25      963.50      963.50     949.10
# 1     INFY     EQ 2017-05-16      951.55      953.10      960.15     946.95
# 2     INFY     EQ 2017-05-17      955.00      951.60      958.45     943.85
# 3     INFY     EQ 2017-05-18      952.80      943.00      973.90     942.85
# 4     INFY     EQ 2017-05-19      961.75      961.50      962.70     947.85
# ..     ...    ...        ...         ...         ...         ...        ...
# 491   INFY     EQ 2019-05-07      718.40      720.40      727.90     718.70
# 492   INFY     EQ 2019-05-08      724.55      721.00      726.00     716.50
# 493   INFY     EQ 2019-05-09      719.35      719.15      730.30     715.80
# 494   INFY     EQ 2019-05-10      721.05      720.80      726.00     715.00
# 495   INFY     EQ 2019-05-13      716.85      716.55      726.45     712.10
#
# ...

# %%
df.groupby(by='Month',axis=0).count()
df.head()
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0   INFY     EQ 2017-05-15      964.25       963.5      963.50     949.10
# 1   INFY     EQ 2017-05-16      951.55       953.1      960.15     946.95
# 2   INFY     EQ 2017-05-17      955.00       951.6      958.45     943.85
# 3   INFY     EQ 2017-05-18      952.80       943.0      973.90     942.85
# 4   INFY     EQ 2017-05-19      961.75       961.5      962.70     947.85
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      953.25       951.55         951.49                3648582
# 1      956.00       955.00         952.92                3065084
# 2      952.90       952.80         949.48                1457754
# 3      960.25       961.75         962.61                4028924
# 4      957.40       957.95         954.18                2128698
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  Year  \
# ...

# %%
df.groupby(by='Year',axis=0).count()
df.head()
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0   INFY     EQ 2017-05-15      964.25       963.5      963.50     949.10
# 1   INFY     EQ 2017-05-16      951.55       953.1      960.15     946.95
# 2   INFY     EQ 2017-05-17      955.00       951.6      958.45     943.85
# 3   INFY     EQ 2017-05-18      952.80       943.0      973.90     942.85
# 4   INFY     EQ 2017-05-19      961.75       961.5      962.70     947.85
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      953.25       951.55         951.49                3648582
# 1      956.00       955.00         952.92                3065084
# 2      952.90       952.80         949.48                1457754
# 3      960.25       961.75         962.61                4028924
# 4      957.40       957.95         954.18                2128698
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  Year  \
# ...

# %%
df = pd.concat([df, pd.DataFrame({'Transactions': df['Average Price']*df['Total Traded Quantity']})], axis = 1)

# %%
df['Transactions'].groupby(df['Month']).sum() / df['Total Traded Quantity'].groupby(df['Month']).sum()
# Out:
# Month
# 1      862.453406
# 2      915.793892
# 3      863.753105
# 4      908.036294
# 5      990.981971
# 6     1100.977879
# 7     1180.248342
# 8     1022.526510
# 9      814.838089
# 10     769.579304
# 11     756.505996
# 12     787.064410
# dtype: float64

# %%
df['Transactions'].groupby(df['Year']).sum() / df['Total Traded Quantity'].groupby(df['Year']).sum()
# Out:
# Year
# 2017    944.251395
# 2018    968.748507
# 2019    725.878490
# dtype: float64

# %%
# Function to calculate the average price over the last N days of the stock price
def avg(n):
    
    return df['Close Price'].tail(n).mean()

# %%
avg(30)
# Out:
# 736.7966666666666

# %%
def profit_and_loss(n):
    k = len(df)
    curr = df['Close Price'][k-1]
    n_old_day = df['Close Price'].tail(n)
    
    return ((curr - n_old_day)/n_old_day)*100

# %%
sum(profit_and_loss(7))
# Out:
# 0.5432114331161041

# %%
sum(profit_and_loss(30))
# Out:
# -62.87373248334804

# %%
sum(profit_and_loss(180))
# Out:
# -277.26122498087506

# %%
sum(profit_and_loss(365))
# Out:
# -7265.659508805403

# %%
df.insert(df.shape[1], 'Day_Perc_Change', df['Close Price'].pct_change())

# %%
df = df.iloc[1:,:]

# %%
df.head()
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 1   INFY     EQ 2017-05-16      951.55       953.1      960.15     946.95
# 2   INFY     EQ 2017-05-17      955.00       951.6      958.45     943.85
# 3   INFY     EQ 2017-05-18      952.80       943.0      973.90     942.85
# 4   INFY     EQ 2017-05-19      961.75       961.5      962.70     947.85
# 5   INFY     EQ 2017-05-22      957.95       958.4      966.90     956.55
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 1      956.00       955.00         952.92                3065084
# 2      952.90       952.80         949.48                1457754
# 3      960.25       961.75         962.61                4028924
# 4      957.40       957.95         954.18                2128698
# 5      960.00       961.45         962.29                2751526
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  Year  \
# ...

# %%
df.insert(df.shape[1], 'Trend', 'Slight')

# %%
df.loc[df['Day_Perc_Change'].between(-0.005, -0.01, inclusive = True), 'Trend'] = 'Slight negative'

df.loc[df['Day_Perc_Change'].between(0.005, 0.01, inclusive = True), 'Trend'] = 'Slight positive'

# %%
df.loc[df['Day_Perc_Change'].between(-0.03, -0.01, inclusive = False),'Trend'] = 'Negative'

df.loc[df['Day_Perc_Change'].between(0.01, 0.03, inclusive = False),'Trend'] = 'Positive'

# %%
df.loc[df['Day_Perc_Change'].between(-0.07, -0.03, inclusive = True),'Trend'] = 'Top losers'

df.loc[df['Day_Perc_Change'].between(0.03, 0.07, inclusive = True),'Trend'] = 'Top gainers'

# %%
df.loc[df['Day_Perc_Change']<-0.07,'Trend']= 'Bear drop'

df.loc[df['Day_Perc_Change']>0.07,'Trend'] = 'Bull run'

# %%
df['Trend'].unique()
# Out:
# array(['Slight', 'Slight positive', 'Positive', 'Negative', 'Top gainers',
#        'Bear drop', 'Top losers'], dtype=object)

# %%
df.head(30)
# Out:
#    Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 1    INFY     EQ 2017-05-16      951.55      953.10      960.15     946.95
# 2    INFY     EQ 2017-05-17      955.00      951.60      958.45     943.85
# 3    INFY     EQ 2017-05-18      952.80      943.00      973.90     942.85
# 4    INFY     EQ 2017-05-19      961.75      961.50      962.70     947.85
# 5    INFY     EQ 2017-05-22      957.95      958.40      966.90     956.55
# 6    INFY     EQ 2017-05-23      961.45      964.65      967.00     954.10
# 7    INFY     EQ 2017-05-24      957.30      960.00      965.50     949.60
# 8    INFY     EQ 2017-05-25      954.80      961.00      986.60     961.00
# 9    INFY     EQ 2017-05-26      983.30      987.00     1000.00     980.60
# 10   INFY     EQ 2017-05-29      995.70      990.90      996.70     975.70
# 11   INFY     EQ 2017-05-30      985.15      982.00     1000.00     978.65
# ...

# %%
df.groupby('Trend')['Total Traded Quantity'].mean()
# Out:
# Trend
# Bear drop          4.878630e+07
# Negative           5.634151e+06
# Positive           6.655530e+06
# Slight             4.872337e+06
# Slight positive    5.848807e+06
# Top gainers        1.259063e+07
# Top losers         1.463854e+07
# Name: Total Traded Quantity, dtype: float64

# %%
df.groupby('Trend')['Total Traded Quantity'].median()
# Out:
# Trend
# Bear drop          48786302.0
# Negative            5088554.0
# Positive            5523811.5
# Slight              4102076.0
# Slight positive     5301784.0
# Top gainers        12042170.5
# Top losers         10985897.0
# Name: Total Traded Quantity, dtype: float64

# %%
df.to_csv('week2.csv')
